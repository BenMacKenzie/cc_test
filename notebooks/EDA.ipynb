# %%
import pandas as pd

# %%
train_df = pd.read_csv('../data/processed/train.csv')
train_df
# Out:
#      age     sex   chest-pain-type  resting-blood-pressure  cholesterol  \
# 0     54    male  non-anginal pain                     125          273
# 1     59    male      asymptomatic                     110          239
# 2     41    male   atypical angina                     110          235
# 3     68    male  non-anginal pain                     118          277
# 4     54  female  non-anginal pain                     108          267
# ..   ...     ...               ...                     ...          ...
# 237   53    male      asymptomatic                     140          203
# 238   42  female      asymptomatic                     102          265
# 239   70    male   atypical angina                     156          245
# 240   55  female      asymptomatic                     180          327
# 241   63  female      asymptomatic                     150          407
#
#      fasting-blood-sugar                   resting-ecg  max-heart-rate  \
# 0                  False  left ventricular hypertrophy             152
# 1                  False  left ventricular hypertrophy             142
# 2                  False                        normal             153
# 3                  False                        normal             151
# 4                  False  left ventricular hypertrophy             167
# ..                   ...                           ...             ...
# 237                 True  left ventricular hypertrophy             155
# 238                False  left ventricular hypertrophy             122
# 239                False  left ventricular hypertrophy             143
# 240                False         ST-T wave abnormality             117
# 241                False  left ventricular hypertrophy             154
#
#     exercise-angina  oldpeak        slope colored-vessels               thal  \
# 0                no      0.5  downsloping               1             normal
# 1               yes      1.2         flat               1  reversable defect
# 2                no      0.0    unsloping               0             normal
# 3                no      1.0    unsloping               1  reversable defect
# 4                no      0.0    unsloping               0             normal
# ..              ...      ...          ...             ...                ...
# 237             yes      3.1  downsloping               0  reversable defect
# 238              no      0.6         flat               0             normal
# 239              no      0.0    unsloping               0             normal
# 240             yes      3.4         flat               0             normal
# 241              no      4.0         flat               3  reversable defect
#
#        datetime  postalcode  narrowing-diagnosis
# 0    2018-10-04       92129                    0
# 1    2018-11-11       92129                    1
# 2    2019-04-04       92129                    0
# 3    2019-01-13       92129                    0
# 4    2019-03-16       92129                    0
# ..          ...         ...                  ...
# 237  2018-08-16       92129                    1
# 238  2019-01-05       92129                    0
# 239  2019-04-22       92129                    0
# 240  2019-03-26       92129                    1
# 241  2018-12-06       92129                    1
#
# [242 rows x 16 columns]

# %%
['sex', 'chest-pain-type', 'fasting-blood-sugar', 'resting-ecg', 'exercise-angina', 'slope', 'thal', 'datetime', 'postalcode', 'narrowing-diagnosis']
# Out:
# Index(['age', 'sex', 'chest-pain-type', 'resting-blood-pressure',
#        'cholesterol', 'fasting-blood-sugar', 'resting-ecg', 'max-heart-rate',
#        'exercise-angina', 'oldpeak', 'slope', 'colored-vessels', 'thal',
#        'datetime', 'postalcode', 'narrowing-diagnosis'],
#       dtype='object')

# %%
train_df.dtypes
# Out:
# age                         int64
# sex                        object
# chest-pain-type            object
# resting-blood-pressure      int64
# cholesterol                 int64
# fasting-blood-sugar          bool
# resting-ecg                object
# max-heart-rate              int64
# exercise-angina            object
# oldpeak                   float64
# slope                      object
# colored-vessels            object
# thal                       object
# datetime                   object
# postalcode                  int64
# narrowing-diagnosis         int64
# dtype: object

# %%
df.oldpeak
# Out:
# 0      2.3
# 1      1.5
# 2      2.6
# 3      3.5
# 4      1.4
#       ...
# 298    1.2
# 299    3.4
# 300    1.2
# 301    0.0
# 302    0.0
# Name: oldpeak, Length: 303, dtype: float64

# %%
from catboost import CatBoostClassifier, Pool
import pandas as pd
from pathlib import Path
project_dir = "../"

data_dir = f"{project_dir}/data/processed"
train_df = pd.read_csv(f"{data_dir}/train.csv")
test_df = pd.read_csv(f"{data_dir}/test.csv")


X_train = train_df.drop(['narrowing-diagnosis'], axis=1)
y_train = train_df['narrowing-diagnosis']

cat_features = ['sex', 'chest-pain-type', 'fasting-blood-sugar', 'resting-ecg', 'exercise-angina',
                'slope', 'thal', 'datetime', 'postalcode']


train_data = Pool(data=X_train, cat_features=cat_features, label=y_train)

X_test = test_df.drop(['narrowing-diagnosis'], axis=1)
y_test = test_df['narrowing-diagnosis']

test_data = Pool(data=X_test, cat_features=cat_features, label=y_test)

model = CatBoostClassifier(iterations=1000, eval_metric="PRAUC", early_stopping_rounds=40)

model.fit(train_data, eval_set=test_data, verbose=False, plot=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# _catboost.pyx in _catboost.get_float_feature()
#
# _catboost.pyx in _catboost._FloatOrNan()
#
# _catboost.pyx in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'?'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-24-816552c53a64> in <module>
#      16
#      17
# ---> 18 train_data = Pool(data=X_train, cat_features=cat_features, label=y_train)
#      19
#      20 X_test = test_df.drop(['narrowing-diagnosis'], axis=1)
#
# ~/projects/feature_store/venv/lib/python3.7/site-packages/catboost/core.py in __init__(self, data, label, cat_features, text_features, embedding_features, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     453                     )
#     454
# --> 455                 self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     456         super(Pool, self).__init__()
#     457
#
# ~/projects/feature_store/venv/lib/python3.7/site-packages/catboost/core.py in _init(self, data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     964             baseline = np.reshape(baseline, (samples_count, -1))
#     965             self._check_baseline_shape(baseline, samples_count)
# --> 966         self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     967
#     968
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_features_order_layout_pool()
#
# _catboost.pyx in _catboost._set_features_order_data_pd_data_frame()
#
# _catboost.pyx in _catboost.create_num_factor_data()
#
# _catboost.pyx in _catboost.get_float_feature()
#
# CatBoostError: Bad value for num_feature[non_default_doc_idx=6,feature_idx=11]="?": Cannot convert 'b'?'' to float

# %%
train_df.iloc[6]
# Out:
# age                                      58
# sex                                    male
# chest-pain-type             atypical angina
# resting-blood-pressure                  125
# cholesterol                             220
# fasting-blood-sugar                   False
# resting-ecg                          normal
# max-heart-rate                          144
# exercise-angina                          no
# oldpeak                                 0.4
# slope                                  flat
# colored-vessels                           ?
# thal                      reversable defect
# datetime                         2019-05-21
# postalcode                            92129
# narrowing-diagnosis                       0
# Name: 6, dtype: object

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Using cached catboost-0.24.4-cp37-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (11.1 MB)
# Requirement already satisfied: numpy>=1.16.0 in /Users/benmackenzie/projects/feature_store/venv/lib/python3.7/site-packages (from catboost) (1.18.2)
# Requirement already satisfied: six in /Users/benmackenzie/projects/feature_store/venv/lib/python3.7/site-packages (from catboost) (1.14.0)
# Requirement already satisfied: pandas>=0.24.0 in /Users/benmackenzie/projects/feature_store/venv/lib/python3.7/site-packages (from catboost) (1.0.3)
# Collecting matplotlib
#   Using cached matplotlib-3.3.3-cp37-cp37m-macosx_10_9_x86_64.whl (8.5 MB)
# Requirement already satisfied: scipy in /Users/benmackenzie/projects/feature_store/venv/lib/python3.7/site-packages (from catboost) (1.4.1)
# Collecting graphviz
#   Using cached graphviz-0.16-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: plotly in /Users/benmackenzie/projects/feature_store/venv/lib/python3.7/site-packages (from catboost) (4.12.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/benmackenzie/projects/feature_store/venv/lib/python3.7/site-packages (from pandas>=0.24.0->catboost) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/benmackenzie/projects/feature_store/venv/lib/python3.7/site-packages (from pandas>=0.24.0->catboost) (2019.3)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-8.1.0-cp37-cp37m-macosx_10_10_x86_64.whl (2.2 MB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.1-cp37-cp37m-macosx_10_9_x86_64.whl (61 kB)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: retrying>=1.3.3 in /Users/benmackenzie/projects/feature_store/venv/lib/python3.7/site-packages (from plotly->catboost) (1.3.3)
# Installing collected packages: cycler, pillow, kiwisolver, pyparsing, matplotlib, graphviz, catboost
# Successfully installed catboost-0.24.4 cycler-0.10.0 graphviz-0.16 kiwisolver-1.3.1 matplotlib-3.3.3 pillow-8.1.0 pyparsing-2.4.7
# WARNING: You are using pip version 20.0.2; however, version 21.0 is available.
# You should consider upgrading via the '/Users/benmackenzie/projects/feature_store/venv/bin/python3.7 -m pip install --upgrade pip' command.
